# %% [markdown]
# # Quesiton
# * A sizable department has to be maintained, for the purposes of recruiting new talent.
#
# * More often than not, the new employees have to be trained for the job and/or given time to acclimatize themselves to the company.
#
# * Hence, the management has contracted an HR analytics firm to understand what factors they should focus on, in order to curb attrition.
#
# * In other words, they want to know what changes they should make to their workplace, in order to get most of their employees to stay.
#
# * Also, they want to know which of these variables is most important and needs to be addressed right away.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('general_data.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.shape
# Out:
# (4410, 24)

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df1 = df.dropna()
df1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df1.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df1.drop_duplicates()
df1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df1[["Age","DistanceFromHome","JobLevel","MonthlyIncome","NumCompaniesWorked",
     "PercentSalaryHike","StockOptionLevel","TotalWorkingYears","TrainingTimesLastYear",
     "YearsAtCompany","YearsSinceLastPromotion","YearsWithCurrManager"]].mean()
# Out:
# Age                           36.933364
# DistanceFromHome               9.198996
# JobLevel                       2.063898
# MonthlyIncome              65061.702419
# NumCompaniesWorked             2.693291
# PercentSalaryHike             15.210634
# StockOptionLevel               0.794614
# TotalWorkingYears             11.290278
# TrainingTimesLastYear          2.798266
# YearsAtCompany                 7.010497
# YearsSinceLastPromotion        2.191693
# YearsWithCurrManager           4.126198
# dtype: float64

# %%
df1[["Age","DistanceFromHome","JobLevel","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
     "StockOptionLevel","TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
     "YearsWithCurrManager"]].median()
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# JobLevel                       2.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# StockOptionLevel               1.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
df1[["Age","DistanceFromHome","JobLevel","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
     "StockOptionLevel","TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
     "YearsWithCurrManager"]].mode()
# Out:
#    Age  DistanceFromHome  JobLevel  MonthlyIncome  NumCompaniesWorked  \
# 0   35                 2         1          23420                 1.0
#
#    PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 0                 11                 0               10.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      2               5                        0
#
#    YearsWithCurrManager
# 0                     2

# %%
df1[["Age","DistanceFromHome","JobLevel","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
     "StockOptionLevel","TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany",
     "YearsSinceLastPromotion","YearsWithCurrManager"]].skew()
# Out:
# Age                        0.413048
# DistanceFromHome           0.955517
# JobLevel                   1.021797
# MonthlyIncome              1.367457
# NumCompaniesWorked         1.029174
# PercentSalaryHike          0.819510
# StockOptionLevel           0.967263
# TotalWorkingYears          1.115419
# TrainingTimesLastYear      0.551818
# YearsAtCompany             1.764619
# YearsSinceLastPromotion    1.980992
# YearsWithCurrManager       0.834277
# dtype: float64

# %%
df1[["Age","DistanceFromHome","JobLevel","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
     "StockOptionLevel","TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany",
     "YearsSinceLastPromotion","YearsWithCurrManager"]].kurt()
# Out:
# Age                       -0.409517
# DistanceFromHome          -0.230691
# JobLevel                   0.388189
# MonthlyIncome              0.990836
# NumCompaniesWorked         0.014307
# PercentSalaryHike         -0.306951
# StockOptionLevel           0.356755
# TotalWorkingYears          0.909316
# TrainingTimesLastYear      0.494215
# YearsAtCompany             3.930726
# YearsSinceLastPromotion    3.592162
# YearsWithCurrManager       0.170703
# dtype: float64

# %%
df1.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4382.000000       4382.000000  4382.000000         4382.0  4382.000000
# mean     36.933364          9.198996     2.912369            1.0  2207.804884
# std       9.137272          8.105396     1.024728            0.0  1271.688783
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1108.250000
# 50%      36.000000          7.000000     3.000000            1.0  2208.500000
# 75%      43.000000         14.000000     4.000000            1.0  3308.750000
# max      60.000000         29.000000     5.000000            1.0  4409.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4382.000000    4382.000000         4382.000000        4382.000000
# mean      2.063898   65061.702419            2.693291          15.210634
# ...

# %% [markdown]
# # Age

# %%
plt.boxplot(df1.Age)
plt.show()

# %%
sns.distplot(df.Age)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# * Therefore, Age is normally distributed

# %% [markdown]
# # Distance From Home

# %%
plt.boxplot(df1.DistanceFromHome)
plt.show()

# %%
sns.distplot(df.DistanceFromHome)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Density'>

# %% [markdown]
# * Not normally distributed and it is positively skewed

# %% [markdown]
# # Monthly Income

# %%
plt.boxplot(df1.MonthlyIncome)
plt.show()

# %%
sns.distplot(df.MonthlyIncome)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %% [markdown]
# * It is positively skewed and have some outliers

# %% [markdown]
# # Num Companies Worked

# %%
plt.boxplot(df1.NumCompaniesWorked)
plt.show()

# %%
sns.distplot(df.NumCompaniesWorked)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Density'>

# %% [markdown]
# * Positively skewed and has one outlier

# %% [markdown]
# # Stock Option Level

# %%
plt.boxplot(df1.StockOptionLevel)
plt.show()

# %%
sns.distplot(df.StockOptionLevel)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='Density'>

# %% [markdown]
# * Not normally distributed and has one outlier

# %% [markdown]
# # TotalWorkingYears

# %%
plt.boxplot(df1.TotalWorkingYears)
plt.show()

# %%
sns.distplot(df.TotalWorkingYears)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Density'>

# %% [markdown]
# * Positively skewed and have some outliers

# %% [markdown]
# # Training Time Last Year

# %%
plt.boxplot(df1.TrainingTimesLastYear)
plt.show()

# %%
sns.distplot(df.TrainingTimesLastYear)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='Density'>

# %% [markdown]
# * Not normally distributed and have some outliers

# %% [markdown]
# # Years At Company

# %%
plt.boxplot(df1.YearsAtCompany)
plt.show()

# %%
sns.distplot(df.YearsAtCompany)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Density'>

# %% [markdown]
# * Positively skewed and have lot of outliers

# %% [markdown]
# # Years Since Last Promotion

# %%
plt.boxplot(df1.YearsSinceLastPromotion)
plt.show()

# %%
sns.distplot(df.YearsSinceLastPromotion)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Density'>

# %% [markdown]
# * Positively skewed and have outliers

# %% [markdown]
# # Years With Curr Manager

# %%
plt.boxplot(df1.YearsWithCurrManager)
plt.show()

# %%
sns.distplot(df.YearsWithCurrManager)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Density'>

# %% [markdown]
# * Not normally distributed and have around 3 outliers

# %% [markdown]
# # Plot against Attrition

# %%
sns.countplot(df1.Attrition)
# Out:
# C:\Users\LR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(x="BusinessTravel",hue='Attrition', data=df1)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
sns.countplot(x="Department",hue='Attrition', data=df1)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
sns.countplot(x="EducationField",hue='Attrition', data=df1)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
sns.countplot(x="Gender",hue='Attrition', data=df1)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="MaritalStatus",hue='Attrition', data=df1)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
df2 = df1.copy()

# %%
df2
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df2.corr()
# Out:
#                               Age  DistanceFromHome  Education  EmployeeCount  \
# Age                      1.000000          0.007376  -0.033900            NaN
# DistanceFromHome         0.007376          1.000000  -0.007491            NaN
# Education               -0.033900         -0.007491   1.000000            NaN
# EmployeeCount                 NaN               NaN        NaN            NaN
# EmployeeID               0.008105         -0.000326  -0.009389            NaN
# JobLevel                -0.001137         -0.039990   0.045822            NaN
# MonthlyIncome           -0.045163         -0.022757   0.007289            NaN
# NumCompaniesWorked       0.299527         -0.014449  -0.016210            NaN
# PercentSalaryHike       -0.032561          0.037720  -0.041054            NaN
# StandardHours                 NaN               NaN        NaN            NaN
# StockOptionLevel        -0.031504          0.009353   0.002386            NaN
# ...

# %%
df3 = df2.drop(['StandardHours','EmployeeCount','Over18'],axis=1)
df3
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                    6          2  Life Sciences           1  Female
# ...

# %%
df3.corr()
# Out:
#                               Age  DistanceFromHome  Education  EmployeeID  \
# Age                      1.000000          0.007376  -0.033900    0.008105
# DistanceFromHome         0.007376          1.000000  -0.007491   -0.000326
# Education               -0.033900         -0.007491   1.000000   -0.009389
# EmployeeID               0.008105         -0.000326  -0.009389    1.000000
# JobLevel                -0.001137         -0.039990   0.045822   -0.003090
# MonthlyIncome           -0.045163         -0.022757   0.007289    0.007865
# NumCompaniesWorked       0.299527         -0.014449  -0.016210    0.000719
# PercentSalaryHike       -0.032561          0.037720  -0.041054   -0.004877
# StockOptionLevel        -0.031504          0.009353   0.002386   -0.013488
# TotalWorkingYears        0.680037          0.009574  -0.009228   -0.001688
# TrainingTimesLastYear   -0.028962         -0.008957   0.009939   -0.012102
# ...

# %% [markdown]
# ### There are many categorical values so we'll use LabelEncoder to make it numerical

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
#encodes'Yes'=1, 'No'=0
df3['Attrition'] = le.fit_transform(df3['Attrition'])

#encodes 'Travel_Rarely'=2, 'Travel_Frequently'=1, 'Non-Tavel'=0
df3['BusinessTravel'] = le.fit_transform(df3['BusinessTravel'])

#encodes 'Sales'=2,'Research & Development'=1,'Human Resources'=0 for Department column
df3['Department'] = le.fit_transform(df3['Department'])

#encodes 'Technical Degree'=5,'Other'=4,'Medical'=3,'Marketing'=2,'Life Sciences'=1,'Human Resources'=0 for EducationField column
df3['EducationField'] = le.fit_transform(df3['EducationField'])

#encodes 'Male'=1,'Female'=0 for Gender column
df3['Gender'] = le.fit_transform(df3['Gender'])

#encodes 'Sales Representative'=8,'Sales Executive'=7,'Research Scientist'=6,'Research Director'=5,'Manufacturing Director'=4,'Manager'=3,'Laboratory Technician'=2,'Human Resources'=1,'Healthcare Representative'=0 in JobRole column
df3['JobRole'] = le.fit_transform(df3['JobRole'])

#encodes 'Single'=2,'Married'=1,'Divorced'=0 in MaritalStatus column
df3['MaritalStatus'] = le.fit_transform(df3['MaritalStatus'])

# %%
df3
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51          0               2           2                 6          2
# 1      31          1               1           1                10          1
# 2      32          0               1           1                17          4
# 3      38          0               0           1                 2          5
# 4      32          0               2           1                10          1
# ...   ...        ...             ...         ...               ...        ...
# 4404   29          0               2           2                 4          3
# 4405   42          0               2           1                 5          4
# 4406   29          0               2           1                 2          4
# 4407   25          0               2           1                25          2
# 4408   42          0               2           2                18          2
#
# ...

# %%
df3.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.158399        0.025044   -0.012117
# Attrition               -0.158399   1.000000        0.000825   -0.044624
# BusinessTravel           0.025044   0.000825        1.000000   -0.009163
# Department              -0.012117  -0.044624       -0.009163    1.000000
# DistanceFromHome         0.007376  -0.009449        0.025066    0.012095
# Education               -0.033900  -0.017106        0.003074   -0.003732
# EducationField           0.044205  -0.057099       -0.016674    0.014810
# EmployeeID               0.008105  -0.004621       -0.003193   -0.001500
# Gender                  -0.040625   0.018396       -0.038942    0.002680
# JobLevel                -0.001137  -0.012382        0.045873    0.004290
# JobRole                  0.012965   0.026708       -0.026282   -0.025953
# MaritalStatus           -0.094472   0.160081        0.027188   -0.044763
# ...

# %%
df3.dropna()
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51          0               2           2                 6          2
# 1      31          1               1           1                10          1
# 2      32          0               1           1                17          4
# 3      38          0               0           1                 2          5
# 4      32          0               2           1                10          1
# ...   ...        ...             ...         ...               ...        ...
# 4404   29          0               2           2                 4          3
# 4405   42          0               2           1                 5          4
# 4406   29          0               2           1                 2          4
# 4407   25          0               2           1                25          2
# 4408   42          0               2           2                18          2
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df3.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Dummies is used to create new columns according to categorical values

# %%
df4=pd.get_dummies(df1,columns=['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus'])
df4
# Out:
#       Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  JobLevel  \
# 0      51                 6          2              1           1         1
# 1      31                10          1              1           2         1
# 2      32                17          4              1           3         4
# 3      38                 2          5              1           4         3
# 4      32                10          1              1           5         1
# ...   ...               ...        ...            ...         ...       ...
# 4404   29                 4          3              1        4405         2
# 4405   42                 5          4              1        4406         1
# 4406   29                 2          4              1        4407         1
# 4407   25                25          2              1        4408         2
# 4408   42                18          2              1        4409         1
#
# ...

# %%
df5=df4.drop(['StandardHours','EmployeeCount','Over18'],axis=1)
df5
# Out:
#       Age  DistanceFromHome  Education  EmployeeID  JobLevel  MonthlyIncome  \
# 0      51                 6          2           1         1         131160
# 1      31                10          1           2         1          41890
# 2      32                17          4           3         4         193280
# 3      38                 2          5           4         3          83210
# 4      32                10          1           5         1          23420
# ...   ...               ...        ...         ...       ...            ...
# 4404   29                 4          3        4405         2          35390
# 4405   42                 5          4        4406         1          60290
# 4406   29                 2          4        4407         1          26790
# 4407   25                25          2        4408         2          37020
# 4408   42                18          2        4409         1          23980
#
# ...

# %%
df5.dropna()
# Out:
#       Age  DistanceFromHome  Education  EmployeeID  JobLevel  MonthlyIncome  \
# 0      51                 6          2           1         1         131160
# 1      31                10          1           2         1          41890
# 2      32                17          4           3         4         193280
# 3      38                 2          5           4         3          83210
# 4      32                10          1           5         1          23420
# ...   ...               ...        ...         ...       ...            ...
# 4404   29                 4          3        4405         2          35390
# 4405   42                 5          4        4406         1          60290
# 4406   29                 2          4        4407         1          26790
# 4407   25                25          2        4408         2          37020
# 4408   42                18          2        4409         1          23980
#
# ...

# %%
df5.corr()
# Out:
#                                         Age  DistanceFromHome  Education  \
# Age                                1.000000          0.007376  -0.033900
# DistanceFromHome                   0.007376          1.000000  -0.007491
# Education                         -0.033900         -0.007491   1.000000
# EmployeeID                         0.008105         -0.000326  -0.009389
# JobLevel                          -0.001137         -0.039990   0.045822
# MonthlyIncome                     -0.045163         -0.022757   0.007289
# NumCompaniesWorked                 0.299527         -0.014449  -0.016210
# PercentSalaryHike                 -0.032561          0.037720  -0.041054
# StockOptionLevel                  -0.031504          0.009353   0.002386
# TotalWorkingYears                  0.680037          0.009574  -0.009228
# TrainingTimesLastYear             -0.028962         -0.008957   0.009939
# YearsAtCompany                     0.311281          0.030746   0.005997
# ...

# %% [markdown]
# # Conclusion:
#
# * It is clear from the correlation that the company should focus on providing good facilities to the newly hired employee and who are unmarried. The company should provide good travel facilities the one who have most frequent business travels.
